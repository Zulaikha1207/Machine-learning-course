# %% [markdown]
# <a href="https://colab.research.google.com/github/Zulaikha1207/Machine-learning-course/blob/master/k_means_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Mall_Customers.csv')
X = dataset.iloc[:, [3, 4]].values

# %% [markdown]
# ## Using the elbow method to find the optimal number of clusters

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ## Training the K-Means model on the dataset

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %% [markdown]
# ## Visualising the clusters

# %%
plt.scatter(X[y_kmeans ==0, 0], X[y_kmeans==0, 1], s= 75, c= 'yellow', label='Cluster1')
plt.scatter(X[y_kmeans ==1, 0], X[y_kmeans==1, 1], s= 75, c= 'pink', label='Cluster2')
plt.scatter(X[y_kmeans ==2, 0], X[y_kmeans==2, 1], s= 75, c= 'green', label='Cluster3')
plt.scatter(X[y_kmeans ==3, 0], X[y_kmeans==3, 1], s= 75, c= 'red', label='Cluster4')
plt.scatter(X[y_kmeans ==4, 0], X[y_kmeans==4, 1], s= 75, c= 'blue', label='Cluster5')
plt.scatter(kmeans.cluster_centers_[:, 0],kmeans.cluster_centers_[:, 1], s=200, c='black', label='centroids')
plt.legend()
plt.title('Clustering the customers')
plt.xlabel('Annual Income')
plt.ylabel('Spending score (1-100)')
plt.show()
